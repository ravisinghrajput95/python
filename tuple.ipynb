# %%
# tuple is an unordered collection of element, which cannot be be modified

host_port = ("192.10.17.6", 8080)
print(type(host_port))

host_port.count(8080)
host_port.index("192.10.17.6")


print(f"Host ip address is: {host_port[0]} and port number is {host_port[1]}")
# Out:
# <class 'tuple'>
# Host ip address is: 192.10.17.6 and port number is 8080

# %%
service_endpoint = ("webserver1", 9090)
print(f"Hostname is: {host_port[0]} and port number is {host_port[1]}")

service_endpoint[0] = "webserver2"
# Out:
# Hostname is: 192.10.17.6 and port number is 8080
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 service_endpoint = ("webserver1", 9090)
#       2 print(f"Hostname is: {host_port[0]} and port number is {host_port[1]}")
# ----> 4 service_endpoint[0] = "webserver2"
#
# TypeError: 'tuple' object does not support item assignment
