# %%
cricketers = ["Virat", "Rohit", "Hardik", "Surya"]
mixed_list = ["/etc/passwd", 0.1 , True , "delete"]

print(type(mixed_list[0]))
print(type(mixed_list[1]))
print(type(mixed_list[2]))
print(type(mixed_list[3]))

print(type(cricketers))

print(cricketers[0])
#print(cricketers[4]) # Indexerror exception

print(cricketers[:1])

print(cricketers[1:-1])

print(cricketers[1:2])
      
print(cricketers[3:4])


cricketers.append("Bumrah")
print(cricketers)


cricketers.insert(1, "Dhoni")
print(cricketers)

cricketers.sort()
print(cricketers)

x = cricketers.count("Dhoni")
print(x)

cricketers.reverse()
print(cricketers)

y = cricketers.copy()
print(y)

cricketers.remove("Surya")
print(cricketers)

y = cricketers.index("Hardik")
print(y)
# Out:
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# <class 'list'>
# Virat
# ['Virat']
# ['Rohit', 'Hardik']
# ['Rohit']
# ['Surya']
# ['Virat', 'Rohit', 'Hardik', 'Surya', 'Bumrah']
# ['Virat', 'Dhoni', 'Rohit', 'Hardik', 'Surya', 'Bumrah']
# ['Bumrah', 'Dhoni', 'Hardik', 'Rohit', 'Surya', 'Virat']
# 1
# ['Virat', 'Surya', 'Rohit', 'Hardik', 'Dhoni', 'Bumrah']
# ['Virat', 'Surya', 'Rohit', 'Hardik', 'Dhoni', 'Bumrah']
# ['Virat', 'Rohit', 'Hardik', 'Dhoni', 'Bumrah']
# 2

# %%
deployment_targets = ["us-east-1", "eu-west-1", "ap-south-east-2"]
print(deployment_targets[0])

deployment_targets.append("us-west-2")
print(deployment_targets)

deployment_targets.insert(1, "eu-central-1")
print(deployment_targets)
# Out:
# us-east-1
# ['us-east-1', 'eu-west-1', 'ap-south-east-2', 'us-west-2']
# ['us-east-1', 'eu-central-1', 'eu-west-1', 'ap-south-east-2', 'us-west-2']
