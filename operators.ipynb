# %%
a=8
b=4
print(f"value of A is : {(a)}")
print(f"value of B is : {(b)}")

print(f"Check the addition of the two numbers")
print(f"addition of the two numbers is: {(a+b)}")

print(f"Check subtraction of the two numbers")
print(f"subtraction of the two numbers is: {(a-b)}")

print(f"Check the division of the two numbers")
print(f"division of the two numbers is: {(a/b)}")

print(f"Check the Multiplication of the two numbers")
print(f"Multiplication of the two numbers is: {(a*b)}")

print(f"Check the exponent of the two numbers")
print(f"Exponent of the two numbers is: {a**b}")

print(f"Check the floor division of the two numbers")
print(f"Floor division of the two numbers is: {a//b}")
# Out:
# value of A is : 8
# value of B is : 4
# Check the addition of the two numbers
# addition of the two numbers is: 12
# Check subtraction of the two numbers
# subtraction of the two numbers is: 4
# Check the division of the two numbers
# division of the two numbers is: 2.0
# Check the Multiplication of the two numbers
# Multiplication of the two numbers is: 32
# Check the exponent of the two numbers
# Exponent of the two numbers is: 4096
# Check the floor division of the two numbers
# Floor division of the two numbers is: 2
